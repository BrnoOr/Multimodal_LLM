# %%
from transformers import AutoProcessor
p = AutoProcessor.from_pretrained("Qwen/Qwen3.5-0.8B-Base")
print("processor:", p.chat_template is not None)
print("tokenizer:", p.tokenizer.chat_template is not None)
# Out:
# processor: False
# tokenizer: True
